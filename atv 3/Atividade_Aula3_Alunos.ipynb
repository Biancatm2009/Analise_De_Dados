# %%
import pandas as pd

# %%
path = r"H:\python\3° etapa\atv 3\Tabela_3_Areas_gerais_de_formacao_na_graduacao.xlsx"

# %%
formacao_bruto = pd.read_excel(path, header=None)

# %%
formacao_bruto
# Out:
#                                                     0         1         2  \
# 0   Tabela 10063 - Pessoas com nível superior comp...       NaN       NaN
# 1        Brasil, Grande Região e Unidade da Federação     Total       NaN
# 2                                                 NaN     Total    Homens
# 3                                              Brasil  25854291  10478534
# 4                                               Norte   1525166    590558
# 5                                            Nordeste   4748933   1744994
# 6                                             Sudeste  12828829   5391638
# 7                                                 Sul   4338861   1768855
# 8                                        Centro-Oeste   2412502    982489
# 9                                            Rondônia    164632     62766
# 10                                               Acre     84300     33291
# 11                                           Amazonas    342566    141059
# ...

# %%
formacao_total = formacao_bruto.iloc[3:36, 0:4]

# %%
formacao_stem = formacao_bruto.iloc[3:36, [0, 4, 5, 6] ]
formacao_stem = formacao_stem.rename(columns={0: "uf"})
formacao_stem = formacao_stem.rename(columns={4: "total"})
formacao_stem = formacao_stem.rename(columns={5: "total_homens"})
formacao_stem = formacao_stem.rename(columns={6: "total_mulheres"})

formacao_stem
# Out:
#                      uf    total total_homens total_mulheres
# 3                Brasil  4149041      2750422        1398619
# 4                 Norte   209657       133055          76601
# 5              Nordeste   621388       389993         231395
# 6               Sudeste  2328122      1588874         739247
# 7                   Sul   662916       427372         235543
# 8          Centro-Oeste   326959       211124         115834
# 9              Rondônia    20538        11863           8675
# 10                 Acre    10364         6237           4128
# 11             Amazonas    52669        34749          17919
# 12              Roraima     8016         4958           3057
# 13                 Pará    86691        55481          31211
# 14                Amapá    11349         7464           3885
# 15            Tocantins    20028        12304           7724
# 16             Maranhão    55068        33820          21248
# ...

# %%
formacao_matematica.to_csv(r"H:\python\3° etapa\atv 3\formacao_matematica.csv", sep = ";", encoding="latin1")

# %%
formacao_saude = formacao_bruto.iloc[3:36, [0, 7, 8, 9] ]
formacao_saude = formacao_saude.rename(columns={0: "uf"})
formacao_saude = formacao_saude.rename(columns={7: "total"})
formacao_saude = formacao_saude.rename(columns={8: "total_homens"})
formacao_saude = formacao_saude.rename(columns={9: "total_mulheres"})

formacao_saude
# Out:
#                      uf    total total_homens total_mulheres
# 3                Brasil  8079707      1677985        6401723
# 4                 Norte   599785       141169         458616
# 5              Nordeste  1822087       363905        1458181
# 6               Sudeste  3652397       768288        2884108
# 7                   Sul  1256291       248574        1007718
# 8          Centro-Oeste   749148       156048         593101
# 9              Rondônia    63584        13963          49622
# 10                 Acre    33379         9121          24258
# 11             Amazonas   121988        30738          91249
# 12              Roraima    23977         5880          18098
# 13                 Pará   248397        58128         190270
# 14                Amapá    36754         9794          26960
# 15            Tocantins    71705        13548          58158
# 16             Maranhão   206222        40667         165555
# ...

# %%
formacao_saude.to_csv(r"H:\python\3° etapa\atv 3\formacao_saude.csv", sep = ";", encoding="latin1")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
formacao_total = formacao_total.rename(columns={0: "uf"})
formacao_total = formacao_total.rename(columns={1: "total"})
formacao_total = formacao_total.rename(columns={2: "total_h"})
formacao_total = formacao_total.rename(columns={3: "total_mulheres"})

# %%
formacao_total
# Out:
#                      uf     total total_homens total_mulheres
# 3                Brasil  25854291     10478534       15375757
# 4                 Norte   1525166       590558         934609
# 5              Nordeste   4748933      1744994        3003939
# 6               Sudeste  12828829      5391638        7437191
# 7                   Sul   4338861      1768855        2570005
# 8          Centro-Oeste   2412502       982489        1430013
# 9              Rondônia    164632        62766         101866
# 10                 Acre     84300        33291          51009
# 11             Amazonas    342566       141059         201507
# 12              Roraima     67045        25585          41460
# 13                 Pará    601096       229285         371811
# 14                Amapá     89191        35085          54106
# 15            Tocantins    176336        63485         112851
# 16             Maranhão    468681       161352         307329
# ...

# %%
# Barras agrupadas: homens x mulheres no Brasil (três recortes)
brasil = pd.DataFrame(
    {
        "area": ["Graduação (total)", "STEM", "Saúde / educação"],
        "homens": [
            formacao_total.loc[formacao_total["uf"] == "Brasil", "total"].item(),
            # formacao_stem.loc[formacao_stem["uf"] == "Brasil", "total_homens"].item()
            # formacao_saude.loc[formacao_saude["uf_regiao"] == "Brasil", "homens"].item(),
        ],
        "mulheres": [
            formacao_total.loc[formacao_total["uf"] == "Brasil", "total"].item(),
            # formacao_stem.loc[formacao_stem["uf"] == "Brasil", "total_mulheres"].item()
            # formacao_saude.loc[formacao_saude["uf_regiao"] == "Brasil", "mulheres"].item(),
        ],
    }
)
brasil_long = brasil.melt(id_vars="area", var_name="sexo", value_name="pessoas")

fig, ax = plt.subplots(figsize=(9, 5))
sns.barplot(data=brasil_long, x="area", y="pessoas", hue="sexo", ax=ax)
ax.set_title("Brasil: pessoas com graduação, por área e sexo")
ax.set_xlabel("Área")
ax.set_ylabel("Pessoas")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Barras agrupadas: homens x mulheres no Brasil (três recortes)
# ----> 2 brasil = pd.DataFrame(
#       3     {
#       4         "area": ["Graduação (total)", "STEM", "Saúde / educação"],
#       5         "homens": [
#       6             formacao_total.loc[formacao_total["uf"] == "Brasil", "total"].item(),
#       7             # formacao_stem.loc[formacao_stem["uf"] == "Brasil", "total_homens"].item()
#       8             # formacao_saude.loc[formacao_saude["uf_regiao"] == "Brasil", "homens"].item(),
#       9         ],
#      10         "mulheres": [
#      11             formacao_total.loc[formacao_total["uf"] == "Brasil", "total"].item(),
#      12             # formacao_stem.loc[formacao_stem["uf"] == "Brasil", "total_mulheres"].item()
# ...

# %% [markdown]
# A tabela deverá ser dividida em 3
# - homens e mulheres por região com curso superior
# - homens e mulheres por região com curso nas áreas de Ciência, Tecnologia, Engenharias e Matemática
# - homens e mulheres por região com curso nas áreas de Educação, Serviços pessoais, Saúde e Bem-estar

# %% [markdown]
# Exemplo 1

# %%
# : = todas as linhas  |  0:4 = colunas 0, 1, 2 e 3 (as 4 primeiras)
formacao_total = formacao_bruto.iloc[3:36, 0:4].copy()

# %%
formacao_total.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres"
]

# %%
formacao_total
# Out:
#               uf_regiao     total total_homens total_mulheres
# 3                Brasil  25854291     10478534       15375757
# 4                 Norte   1525166       590558         934609
# 5              Nordeste   4748933      1744994        3003939
# 6               Sudeste  12828829      5391638        7437191
# 7                   Sul   4338861      1768855        2570005
# 8          Centro-Oeste   2412502       982489        1430013
# 9              Rondônia    164632        62766         101866
# 10                 Acre     84300        33291          51009
# 11             Amazonas    342566       141059         201507
# 12              Roraima     67045        25585          41460
# 13                 Pará    601096       229285         371811
# 14                Amapá     89191        35085          54106
# 15            Tocantins    176336        63485         112851
# 16             Maranhão    468681       161352         307329
# ...

# %%
formacao_total["percentual_mulheres"] = ((formacao_total['total_mulheres'] / formacao_total['total']) * 100).round(2)
